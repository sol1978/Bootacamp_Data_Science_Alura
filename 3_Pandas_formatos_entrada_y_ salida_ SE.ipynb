# %% [markdown]
# #Creando Nombres

# %%
import pandas as pd

# %%
df = pd.read_json("https://raw.githubusercontent.com/ElProfeAlejo/tratamiento_datos_python/main/ranking.json")
nombres_m = df[df['sexo'] == 'M'].sample(200)
nombres_f = df[df['sexo'] == 'F'].sample(200)

# %%
nombres_m
# Out:
#          nome  regiao    freq  rank sexo
# 106     ARTUR       0  131972   107    M
# 31    RICARDO       0  467835    32    M
# 108    VALTER       0  131037   109    M
# 58       DAVI       0  254088    59    M
# 194     ODAIR       0   67758   195    M
# ..        ...     ...     ...   ...  ...
# 60   JEFERSON       0  252171    61    M
# 104  REINALDO       0  133930   105    M
# 198    ALVARO       0   65444   199    M
# 119    MOISES       0  124697   120    M
# 160    MOACIR       0   79629   161    M
#
# [200 rows x 5 columns]

# %%
nombres_f
# Out:
#          nome  regiao    freq  rank sexo
# 203   ANTONIA       0  588783     4    F
# 248    RAQUEL       0  284610    49    F
# 393  LUCILENE       0   82838   194    F
# 246   FABIANA       0  290538    47    F
# 285    HELENA       0  197065    86    F
# ..        ...     ...     ...   ...  ...
# 298     THAIS       0  168816    99    F
# 373   GERALDA       0   91752   174    F
# 396   IVONETE       0   81878   197    F
# 214   JESSICA       0  456472    15    F
# 247     LUCIA       0  287153    48    F
#
# [200 rows x 5 columns]

# %%
type (nombres_f)
# Out:
# pandas.core.frame.DataFrame

# %%
print("Cantidad de nombres :" + str(len(nombres_m) + len(nombres_f)))
# Out:
# Cantidad de nombres :400

# %%
frames = [nombres_m, nombres_f]
frames
# Out:
# [         nome  regiao    freq  rank sexo
#  106     ARTUR       0  131972   107    M
#  31    RICARDO       0  467835    32    M
#  108    VALTER       0  131037   109    M
#  58       DAVI       0  254088    59    M
#  194     ODAIR       0   67758   195    M
#  ..        ...     ...     ...   ...  ...
#  60   JEFERSON       0  252171    61    M
#  104  REINALDO       0  133930   105    M
#  198    ALVARO       0   65444   199    M
#  119    MOISES       0  124697   120    M
#  160    MOACIR       0   79629   161    M
#
#  [200 rows x 5 columns],
#           nome  regiao    freq  rank sexo
#  203   ANTONIA       0  588783     4    F
#  248    RAQUEL       0  284610    49    F
#  393  LUCILENE       0   82838   194    F
#  246   FABIANA       0  290538    47    F
#  285    HELENA       0  197065    86    F
#  ..        ...     ...     ...   ...  ...
#  298     THAIS       0  168816    99    F
#  373   GERALDA       0   91752   174    F
#  396   IVONETE       0   81878   197    F
#  214   JESSICA       0  456472    15    F
#  247     LUCIA       0  287153    48    F
#
#  [200 rows x 5 columns]]

# %%
nombres = pd.concat (frames)['nome'].to_frame ()
nombres.columns = ['nombre']

# %%
nombres.sample (5)
# Out:
#         nombre
# 272   CAROLINE
# 243  TEREZINHA
# 351   SEVERINA
# 286   CRISTINA
# 123    EVANDRO

# %% [markdown]
# #Incluyendo ID de alumnos

# %%
nombres.sample (5)
# Out:
#       nombre
# 74      ALAN
# 267    PAULA
# 19   RODRIGO
# 55    FLAVIO
# 108   VALTER

# %%
import numpy as np

# %%
np.random.seed(123)

# %%
total_alumnos = len (nombres)
total_alumnos
# Out:
# 400

# %%
#Para crear una nueva columna en pandas y generar ids de forma aleatoria
nombres ['id_alumno'] = np.random.permutation (total_alumnos)+1
nombres.sample (5)
# Out:
#        nombre  id_alumno
# 37      EDSON        369
# 99    WILLIAN        303
# 246   FABIANA        382
# 351  SEVERINA         33
# 266  PRISCILA        111

# %%
dominios = ['@dominiodemail.com', '@serviciodemail.com']

# %%
nombres['dominio'] = np.random.choice (dominios, total_alumnos)
nombres.sample (5)
# Out:
#         nombre  id_alumno              dominio
# 375  ALEXANDRA         78   @dominiodemail.com
# 203    ANTONIA        331  @serviciodemail.com
# 264    VIVIANE        340   @dominiodemail.com
# 145      ITALO        174   @dominiodemail.com
# 80     EMERSON         45   @dominiodemail.com

# %%
nombres ['email'] = nombres.nombre.str.cat(nombres.dominio).str.lower ()
nombres.sample (10)
# Out:
#        nombre  id_alumno              dominio                        email
# 217   LUCIANA        320   @dominiodemail.com    luciana@dominiodemail.com
# 99    WILLIAN        303  @serviciodemail.com   willian@serviciodemail.com
# 72   GILBERTO        221   @dominiodemail.com   gilberto@dominiodemail.com
# 83      RENAN          8   @dominiodemail.com      renan@dominiodemail.com
# 16    EDUARDO        137   @dominiodemail.com    eduardo@dominiodemail.com
# 144  VINICIOS        265  @serviciodemail.com  vinicios@serviciodemail.com
# 300    ROSELI        327   @dominiodemail.com     roseli@dominiodemail.com
# 136    NILTON        167   @dominiodemail.com     nilton@dominiodemail.com
# 205   JULIANA        365  @serviciodemail.com   juliana@serviciodemail.com
# 393  LUCILENE        205   @dominiodemail.com   lucilene@dominiodemail.com

# %% [markdown]
# #Creando cursos
#  https://www.tiobe.com/tiobe-index/

# %%
import html5lib

# %%
url = 'https://www.tiobe.com/tiobe-index/'

# %%
cursos = pd.read_html(url)
cursos
# Out:
# [    Sep 2023  Sep 2022  Change  Programming Language Programming Language.1  \
#  0          1         1     NaN                   NaN                 Python
#  1          2         2     NaN                   NaN                      C
#  2          3         4     NaN                   NaN                    C++
#  3          4         3     NaN                   NaN                   Java
#  4          5         5     NaN                   NaN                     C#
#  5          6         7     NaN                   NaN             JavaScript
#  6          7         6     NaN                   NaN           Visual Basic
#  7          8        10     NaN                   NaN                    PHP
#  8          9         8     NaN                   NaN      Assembly language
#  9         10         9     NaN                   NaN                    SQL
#  10        11        15     NaN                   NaN                Fortran
#  11        12        12     NaN                   NaN                     Go
#  12        13        14     NaN                   NaN                 MATLAB
#  13        14        22     NaN                   NaN                Scratch
#  14        15        13     NaN                   NaN   Delphi/Object Pascal
#  15        16        16     NaN                   NaN                  Swift
#  16        17        26     NaN                   NaN                   Rust
#  17        18        18     NaN                   NaN                      R
#  18        19        20     NaN                   NaN                   Ruby
#  19        20        34     NaN                   NaN                 Kotlin
#
#     Ratings Change.1
#  0   14.16%   -1.58%
#  1   11.27%   -2.70%
#  2   10.65%   +0.90%
#  3    9.49%   -2.23%
#  4    7.31%   +2.42%
#  5    3.30%   +0.48%
#  6    2.22%   -2.18%
#  7    1.55%   -0.13%
#  8    1.53%   -0.96%
#  9    1.44%   -0.57%
#  10   1.28%   +0.26%
#  11   1.19%   +0.03%
#  12   1.19%   +0.13%
#  13   1.08%   +0.51%
#  14   1.02%   -0.07%
#  15   1.00%   +0.02%
#  16   0.97%   +0.47%
#  17   0.97%   +0.02%
#  18   0.95%   +0.30%
#  19   0.90%   +0.59%  ,
#      Position  Programming Language Ratings
#  0         21                 COBOL   0.88%
#  1         22                   Ada   0.84%
#  2         23  Classic Visual Basic   0.82%
#  3         24                   SAS   0.80%
#  4         25                 Julia   0.79%
#  5         26                  Perl   0.73%
#  6         27       (Visual) FoxPro   0.69%
#  7         28               Haskell   0.65%
#  8         29           Objective-C   0.60%
#  9         30                  Lisp   0.59%
#  10        31                Prolog   0.51%
#  11        32                   Lua   0.51%
#  12        33                  Dart   0.50%
#  13        34          Transact-SQL   0.48%
#  14        35                  GAMS   0.47%
#  15        36                PL/SQL   0.44%
#  16        37                     D   0.43%
#  17        38              VBScript   0.40%
#  18        39                 Scala   0.36%
#  19        40                  Logo   0.34%
#  20        41            PowerShell   0.31%
#  21        42                  CFML   0.31%
#  22        43                  Icon   0.29%
#  23        44                   X++   0.29%
#  24        45                   Awk   0.26%
#  25        46                    F#   0.26%
#  26        47                 Forth   0.26%
#  27        48                  ABAP   0.25%
#  28        49                  PL/I   0.24%
#  29        50                    ML   0.24%,
#     Programming Language 2023 2018 2013 2008 2003 1998 1993 1988
#  0                Python    1    4    8    7   12   25   18    -
#  1                     C    2    2    1    2    2    1    1    1
#  2                   C++    3    3    4    4    3    2    2    4
#  3                  Java    4    1    2    1    1   18    -    -
#  4                    C#    5    5    5    8    9    -    -    -
#  5          Visual Basic    6   17    -    -    -    -    -    -
#  6            JavaScript    7    7   10    9    8   22    -    -
#  7                   SQL    8  251    -    -    7    -    -    -
#  8                   PHP    9    8    6    5    6    -    -    -
#  9     Assembly language   10   12    -    -    -    -    -    -
#  10              Fortran   20   30   27   22   13    7    3   16
#  11          Objective-C   23   15    3   41   58    -    -    -
#  12                  Ada   26   29   20   19   16   15    6    3
#  13                 Lisp   29   31   13   17   14    9    7    2
#  14       (Visual) Basic    -    -    7    3    5    3    5    7,
#      Year        Winner
#  0   2022           C++
#  1   2021        Python
#  2   2020        Python
#  3   2019             C
#  4   2018        Python
#  5   2017             C
#  6   2016            Go
#  7   2015          Java
#  8   2014    JavaScript
#  9   2013  Transact-SQL
#  10  2012   Objective-C
#  11  2011   Objective-C
#  12  2010        Python
#  13  2009            Go
#  14  2008             C
#  15  2007        Python
#  16  2006          Ruby
#  17  2005          Java
#  18  2004           PHP
#  19  2003           C++]

# %%
type (cursos)
# Out:
# list

# %%
cursos = pd.DataFrame(cursos)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py:568: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
type (cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos = pd.read_html(url)
cursos = cursos[2].iloc[:,:1]
cursos.head()
# Out:
#   Programming Language
# 0               Python
# 1                    C
# 2                  C++
# 3                 Java
# 4                   C#

# %% [markdown]
# #Cambiando el index

# %%
cursos
# Out:
#    Programming Language
# 0                Python
# 1                     C
# 2                   C++
# 3                  Java
# 4                    C#
# 5          Visual Basic
# 6            JavaScript
# 7                   SQL
# 8                   PHP
# 9     Assembly language
# 10              Fortran
# 11          Objective-C
# 12                  Ada
# 13                 Lisp
# 14       (Visual) Basic

# %%
cursos = cursos.rename (columns = {'Programming Language': 'nombre_curso'})

# %%
cursos
# Out:
#          nombre_curso
# 0              Python
# 1                   C
# 2                 C++
# 3                Java
# 4                  C#
# 5        Visual Basic
# 6          JavaScript
# 7                 SQL
# 8                 PHP
# 9   Assembly language
# 10            Fortran
# 11        Objective-C
# 12                Ada
# 13               Lisp
# 14     (Visual) Basic

# %%
cursos['id'] = cursos.index + 1
cursos
# Out:
#          nombre_curso  id
# 0              Python   1
# 1                   C   2
# 2                 C++   3
# 3                Java   4
# 4                  C#   5
# 5        Visual Basic   6
# 6          JavaScript   7
# 7                 SQL   8
# 8                 PHP   9
# 9   Assembly language  10
# 10            Fortran  11
# 11        Objective-C  12
# 12                Ada  13
# 13               Lisp  14
# 14     (Visual) Basic  15

# %%
cursos = cursos.set_index ('id')
cursos.head ()
# Out:
#    nombre_curso
# id
# 1        Python
# 2             C
# 3           C++
# 4          Java
# 5            C#

# %%
cursos.shape
# Out:
# (15, 1)

# %% [markdown]
# #Matriculando estudiantes

# %%
nombres
# Out:
#       nombre  id_alumno              dominio                       email
# 106    ARTUR        235   @dominiodemail.com     artur@dominiodemail.com
# 31   RICARDO         43  @serviciodemail.com  ricardo@serviciodemail.com
# 108   VALTER        304  @serviciodemail.com   valter@serviciodemail.com
# 58      DAVI        156   @dominiodemail.com      davi@dominiodemail.com
# 194    ODAIR        343  @serviciodemail.com    odair@serviciodemail.com
# ..       ...        ...                  ...                         ...
# 298    THAIS        231   @dominiodemail.com     thais@dominiodemail.com
# 373  GERALDA         99  @serviciodemail.com  geralda@serviciodemail.com
# 396  IVONETE        323   @dominiodemail.com   ivonete@dominiodemail.com
# 214  JESSICA        383   @dominiodemail.com   jessica@dominiodemail.com
# 247    LUCIA        366  @serviciodemail.com    lucia@serviciodemail.com
#
# [400 rows x 4 columns]

# %%
nombres ['matriculas'] =np.random.exponential(size =  total_alumnos).astype(int)
nombres.head()
# Out:
#       nombre  id_alumno              dominio                       email  \
# 106    ARTUR        235   @dominiodemail.com     artur@dominiodemail.com
# 31   RICARDO         43  @serviciodemail.com  ricardo@serviciodemail.com
# 108   VALTER        304  @serviciodemail.com   valter@serviciodemail.com
# 58      DAVI        156   @dominiodemail.com      davi@dominiodemail.com
# 194    ODAIR        343  @serviciodemail.com    odair@serviciodemail.com
#
#      matriculas
# 106           0
# 31            0
# 108           2
# 58            3
# 194           0

# %%
nombres ['matriculas'] =np.ceil(np.random.exponential (size =  total_alumnos)).astype(int)
nombres.head()
# Out:
#       nombre  id_alumno              dominio                       email  \
# 106    ARTUR        235   @dominiodemail.com     artur@dominiodemail.com
# 31   RICARDO         43  @serviciodemail.com  ricardo@serviciodemail.com
# 108   VALTER        304  @serviciodemail.com   valter@serviciodemail.com
# 58      DAVI        156   @dominiodemail.com      davi@dominiodemail.com
# 194    ODAIR        343  @serviciodemail.com    odair@serviciodemail.com
#
#      matriculas
# 106           2
# 31            1
# 108           1
# 58            1
# 194           2

# %%
nombres ['matriculas'] =np.ceil(np.random.exponential (size =  total_alumnos)*1.5).astype (int)
nombres.head ()
# Out:
#       nombre  id_alumno              dominio                       email  \
# 106    ARTUR        235   @dominiodemail.com     artur@dominiodemail.com
# 31   RICARDO         43  @serviciodemail.com  ricardo@serviciodemail.com
# 108   VALTER        304  @serviciodemail.com   valter@serviciodemail.com
# 58      DAVI        156   @dominiodemail.com      davi@dominiodemail.com
# 194    ODAIR        343  @serviciodemail.com    odair@serviciodemail.com
#
#      matriculas
# 106           1
# 31            1
# 108           7
# 58            1
# 194           3

# %%
nombres.sort_index (inplace = True)
nombres
# Out:
#         nombre  id_alumno              dominio                        email  \
# 0         JOSE         53  @serviciodemail.com      jose@serviciodemail.com
# 1         JOAO         20   @dominiodemail.com       joao@dominiodemail.com
# 2      ANTONIO        157  @serviciodemail.com   antonio@serviciodemail.com
# 3    FRANCISCO        144   @dominiodemail.com  francisco@dominiodemail.com
# 4       CARLOS        397   @dominiodemail.com     carlos@dominiodemail.com
# ..         ...        ...                  ...                          ...
# 395     ROSANE        305  @serviciodemail.com    rosane@serviciodemail.com
# 396    IVONETE        323   @dominiodemail.com    ivonete@dominiodemail.com
# 397    LUCIANE        332   @dominiodemail.com    luciane@dominiodemail.com
# 398    ISADORA        312   @dominiodemail.com    isadora@dominiodemail.com
# 399      NILZA         65   @dominiodemail.com      nilza@dominiodemail.com
#
#      matriculas
# 0             1
# 1             3
# 2             1
# 3             1
# 4             1
# ..          ...
# 395           1
# 396           2
# 397           3
# 398           5
# 399           6
#
# [400 rows x 5 columns]

# %%
nombres.describe()
# Out:
#         id_alumno  matriculas
# count  400.000000  400.000000
# mean   200.500000    2.022500
# std    115.614301    1.499204
# min      1.000000    1.000000
# 25%    100.750000    1.000000
# 50%    200.500000    2.000000
# 75%    300.250000    2.250000
# max    400.000000   12.000000

# %%
nombres.matriculas.describe()
# Out:
# count    400.000000
# mean       2.022500
# std        1.499204
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.250000
# max       12.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.displot (nombres.matriculas)

# %%
nombres.matriculas.value_counts ()
# Out:
# 1     199
# 2     101
# 3      52
# 4      23
# 6      10
# 5       8
# 8       3
# 7       2
# 12      1
# 10      1
# Name: matriculas, dtype: int64

# %% [markdown]
# #Seleccionando alumnos

# %%
nombres.head()
# Out:
#       nombre  id_alumno              dominio                        email  \
# 0       JOSE         53  @serviciodemail.com      jose@serviciodemail.com
# 1       JOAO         20   @dominiodemail.com       joao@dominiodemail.com
# 2    ANTONIO        157  @serviciodemail.com   antonio@serviciodemail.com
# 3  FRANCISCO        144   @dominiodemail.com  francisco@dominiodemail.com
# 4     CARLOS        397   @dominiodemail.com     carlos@dominiodemail.com
#
#    matriculas
# 0           1
# 1           3
# 2           1
# 3           1
# 4           1

# %%
cursos.head()
# Out:
#    nombre_curso
# id
# 1        Python
# 2             C
# 3           C++
# 4          Java
# 5            C#

# %%
todas_matriculas =[]
x = np.random.rand (len (cursos))
prob = x /sum (x)
prob
# Out:
# array([0.04814298, 0.10887202, 0.08425249, 0.08914813, 0.0470237 ,
#        0.01084908, 0.08606198, 0.10748278, 0.08327805, 0.08690581,
#        0.10082149, 0.00647628, 0.03233711, 0.08874248, 0.01960562])

# %%
for index,row in nombres.iterrows():
  id = row.id_alumno
  matriculas =row.matriculas
  for i in range (matriculas):
    mat =[id, np.random.choice (cursos.index, p = prob)]
    todas_matriculas.append (mat)

matriculas = pd.DataFrame (todas_matriculas, columns = ['id_alumno','id_curso'])
matriculas. head()
# Out:
#    id_alumno  id_curso
# 0         53         4
# 1         20         1
# 2         20         3
# 3         20         1
# 4        157        11

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nombre_curso'])[['nombre_curso', 'id_alumno']].rename(columns={'id_alumno':'Total'}).sort_values('Total', ascending = False)
matriculas_por_curso
# Out:
#                nombre_curso  Total
# id_curso
# 8                       SQL     91
# 11                  Fortran     89
# 2                         C     84
# 9                       PHP     78
# 7                JavaScript     74
# 14                     Lisp     74
# 3                       C++     69
# 10        Assembly language     65
# 4                      Java     58
# 1                    Python     43
# 13                      Ada     30
# 5                        C#     25
# 15           (Visual) Basic     11
# 6              Visual Basic     10
# 12              Objective-C      8

# %% [markdown]
# #Salidas en diferentes formatos

# %%
matriculas_por_curso
# Out:
#                nombre_curso  Total
# id_curso
# 8                       SQL     91
# 11                  Fortran     89
# 2                         C     84
# 9                       PHP     78
# 7                JavaScript     74
# 14                     Lisp     74
# 3                       C++     69
# 10        Assembly language     65
# 4                      Java     58
# 1                    Python     43
# 13                      Ada     30
# 5                        C#     25
# 15           (Visual) Basic     11
# 6              Visual Basic     10
# 12              Objective-C      8

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index = False)

# %%
matriculas_por_curso.to_json('matriculas_por_curso.json')

# %%
matriculas_por_curso.to_html('matriculas_por_curso.html', index = False)

# %% [markdown]
# #Creando Banco SQL

# %%
#Funciones actualizadas SQL: https://docs.sqlalchemy.org/en/14/core/connections.html#sqlalchemy.engine.Engine.table_names

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
matriculas_por_curso.head ()
# Out:
#          nombre_curso  Total
# id_curso
# 8                 SQL     91
# 11            Fortran     89
# 2                   C     84
# 9                 PHP     78
# 7          JavaScript     74

# %%
engine = create_engine('sqlite://')
inspection = inspect(engine)

# %%
matriculas_por_curso.to_sql('matriculas', engine)
inspection.get_table_names()
# Out:
# ['matriculas']

# %%
#Para guardar un DataFrame en el banco de datos, usamos la función to_sql(), y pasamos 2 argumentos como parámetro: el nombre de la tabla que se guardará en la base de datos y el motor engine.

# %% [markdown]
# #Buscando en Banco SQL

# %%
query = 'select * from matriculas where total < 20'

# %%
pd.read_sql(sql=text(query), con=engine.connect())
# Out:
#    id_curso    nombre_curso  Total
# 0        15  (Visual) Basic     11
# 1         6    Visual Basic     10
# 2        12     Objective-C      8

# %%
pd.read_sql_table('matriculas', con=engine.connect(), columns=['nombre_curso', 'Total'])
# Out:
#          nombre_curso  Total
# 0                 SQL     91
# 1             Fortran     89
# 2                   C     84
# 3                 PHP     78
# 4          JavaScript     74
# 5                Lisp     74
# 6                 C++     69
# 7   Assembly language     65
# 8                Java     58
# 9              Python     43
# 10                Ada     30
# 11                 C#     25
# 12     (Visual) Basic     11
# 13       Visual Basic     10
# 14        Objective-C      8

# %%
muchas_matriculas =  pd.read_sql_table('matriculas', con=engine.connect(), columns=['nombre_curso', 'Total'])
muchas_matriculas
# Out:
#          nombre_curso  Total
# 0                 SQL     91
# 1             Fortran     89
# 2                   C     84
# 3                 PHP     78
# 4          JavaScript     74
# 5                Lisp     74
# 6                 C++     69
# 7   Assembly language     65
# 8                Java     58
# 9              Python     43
# 10                Ada     30
# 11                 C#     25
# 12     (Visual) Basic     11
# 13       Visual Basic     10
# 14        Objective-C      8

# %%
muchas_matriculas = muchas_matriculas.query('Total > 80')
muchas_matriculas
# Out:
#   nombre_curso  Total
# 0          SQL     91
# 1      Fortran     89
# 2            C     84

# %% [markdown]
# #Escribiendo en el Banco SQL

# %%
muchas_matriculas.to_sql('muchas_matriculas', engine)
# Out:
# 3

# %%
insp = inspect(engine)
print(insp.get_table_names())
# Out:
# ['matriculas', 'muchas_matriculas']

# %% [markdown]
# #Nombres para el ingreso

# %%
matriculas.sample (5)
# Out:
#      id_alumno  id_curso
# 170        145         9
# 20         386         2
# 552         61         4
# 674        321        14
# 778         47         2

# %%
id_curso = 14
proxima_clase = matriculas.query('id_curso == {}'.format(id_curso))
proxima_clase
# Out:
#      id_alumno  id_curso
# 24         314        14
# 42         191        14
# 44         191        14
# 60          12        14
# 68         228        14
# ..         ...       ...
# 738         58        14
# 742        170        14
# 748        244        14
# 756        216        14
# 768        127        14
#
# [74 rows x 2 columns]

# %%
nombres.sample (5)
# Out:
#        nombre  id_alumno              dominio                       email  \
# 393  LUCILENE        205   @dominiodemail.com  lucilene@dominiodemail.com
# 19    RODRIGO        275   @dominiodemail.com   rodrigo@dominiodemail.com
# 295    ANDREA        351  @serviciodemail.com   andrea@serviciodemail.com
# 36    ROBERTO        232  @serviciodemail.com  roberto@serviciodemail.com
# 225   BEATRIZ        355   @dominiodemail.com   beatriz@dominiodemail.com
#
#      matriculas
# 393           1
# 19            1
# 295           1
# 36            5
# 225           1

# %%
proxima_clase.set_index('id_alumno').join(nombres.set_index('id_alumno'))
# Out:
#            id_curso      nombre              dominio  \
# id_alumno
# 7                14       OSMAR   @dominiodemail.com
# 12               14    LEONARDO   @dominiodemail.com
# 13               14    HENRIQUE  @serviciodemail.com
# 14               14     LUCIANO   @dominiodemail.com
# 17               14      BIANCA  @serviciodemail.com
# ...             ...         ...                  ...
# 366              14       LUCIA  @serviciodemail.com
# 368              14       BRENO  @serviciodemail.com
# 368              14       BRENO  @serviciodemail.com
# 391              14  ALESSANDRO   @dominiodemail.com
# 396              14        JAIR  @serviciodemail.com
#
#                                   email  matriculas
# id_alumno
# 7               osmar@dominiodemail.com           6
# 12           leonardo@dominiodemail.com           6
# 13          henrique@serviciodemail.com           3
# 14            luciano@dominiodemail.com           2
# 17            bianca@serviciodemail.com           4
# ...                                 ...         ...
# 366            lucia@serviciodemail.com           3
# 368            breno@serviciodemail.com          10
# 368            breno@serviciodemail.com          10
# 391        alessandro@dominiodemail.com           2
# 396             jair@serviciodemail.com           1
#
# [74 rows x 5 columns]

# %%
proxima_clase.set_index('id_alumno').join(nombres.set_index('id_alumno'))['nombre']
# Out:
# id_alumno
# 7           OSMAR
# 12       LEONARDO
# 13       HENRIQUE
# 14        LUCIANO
# 17         BIANCA
#           ...
# 366         LUCIA
# 368         BRENO
# 368         BRENO
# 391    ALESSANDRO
# 396          JAIR
# Name: nombre, Length: 74, dtype: object

# %%
proxima_clase.set_index('id_alumno').join(nombres.set_index('id_alumno'))['nombre'].to_frame()
# Out:
#                nombre
# id_alumno
# 7               OSMAR
# 12           LEONARDO
# 13           HENRIQUE
# 14            LUCIANO
# 17             BIANCA
# ...               ...
# 366             LUCIA
# 368             BRENO
# 368             BRENO
# 391        ALESSANDRO
# 396              JAIR
#
# [74 rows x 1 columns]

# %%
cursos.sample (5)
# Out:
#          nombre_curso
# id
# 13                Ada
# 10  Assembly language
# 8                 SQL
# 12        Objective-C
# 4                Java

# %%
nombre_aula = cursos.loc[id_curso]
nombre_aula
# Out:
# nombre_curso    Lisp
# Name: 14, dtype: object

# %%
nombre_aula = nombre_aula.nombre_curso
nombre_aula
# Out:
# 'Lisp'

# %%
proxima_clase = proxima_clase.set_index('id_alumno').join(nombres.set_index('id_alumno'))['nombre'].to_frame()

# %%
proxima_clase = proxima_clase.rename(columns={'nombre': 'Alumnos del curso de {}'.format(nombre_aula)})
proxima_clase.sample(5)
# Out:
#           Alumnos del curso de Lisp
# id_alumno
# 343                           ODAIR
# 200                        VALDEMIR
# 166                         MICHAEL
# 368                           BRENO
# 286                          WILIAN

# %% [markdown]
# #Excel

# %%
proxima_clase.to_excel('proxima_clase.xlsx', index = False)

# %%
pd.read_excel('proxima_clase.xlsx')
# Out:
#    Alumnos del curso de Lisp
# 0                      OSMAR
# 1                   LEONARDO
# 2                   HENRIQUE
# 3                    LUCIANO
# 4                     BIANCA
# ..                       ...
# 69                     LUCIA
# 70                     BRENO
# 71                     BRENO
# 72                ALESSANDRO
# 73                      JAIR
#
# [74 rows x 1 columns]
