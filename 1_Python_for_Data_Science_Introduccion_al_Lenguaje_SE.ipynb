# %% [markdown]
# #**Python para DS - Introducción al lenguaje**

# %%
1+1
# Out:
# 2

# %%
'Sole'
# Out:
# 'Sole'

# %%
nombre = 'Sole'

# %%
nombre
# Out:
# 'Sole'

# %%
edad = 45

# %%
edad
# Out:
# 45

# %%
print ('El nombre es Sole y su edad es 45')
# Out:
# El nombre es Sole y su edad es 45

# %% [markdown]
# ## Mi primera función

# %%
suma_dos_numeros = 1232 + 2314
suma_dos_numeros
# Out:
# 3546

# %%
print (f'El nombre es {nombre} y su edad es {edad}')
# Out:
# El nombre es Sole y su edad es 45

# %%
def saludar ():
  nombre = input ('Digite su nombre:')
  print (f'Hola {nombre} sea bienvenido ¡¡¡')

# %%
saludar ()
# Out:
# Digite su nombre:Soledad
# Hola Soledad sea bienvenido ¡¡¡

# %%
def nombre_completo():
   primer_nombre = input('¿Cuál es tu primer nombre? ')
   apellido = input('¿Cuál es tu apellido? ')
   nombre_completo = primer_nombre + ' ' + apellido
   print(nombre_completo)
nombre_completo()
# Out:
# ¿Cuál es tu primer nombre? Soledad
# ¿Cuál es tu apellido? Echeverria
# Soledad Echeverria

# %% [markdown]
# #Parametros

# %%
nombre = 'Andrea'

# %%
def saludar_con_parametros (nombre):
  print (f'Hola {nombre} sea bienvenido ¡¡¡')

# %%
saludar_con_parametros (nombre)
# Out:
# Hola Andrea sea bienvenido ¡¡¡

# %%
def velocidad(espacio, tiempo):
 v = espacio / tiempo
 print(f'Velocidad: {v} m/s')

velocidad(100, 20)
# Out:
# Velocidad: 5.0 m/s

# %% [markdown]
# #Condicionales

# %%
edad = 17

# %%
def verificar_si_puede_conducir (edad):
  if edad >= 18:
    print("Usted tiene edad suficiente para conducir")
  else:
    print ("Usted NO tiene edad suficiente para conducir")


verificar_si_puede_conducir(edad)
# Out:
# Usted NO tiene edad suficiente para conducir

# %%
def clasificar_nps(nota):
  if nota <= 6:
    print('El alumno es considerado Detractor')
  else:
    if nota <= 8:
      print('El alumno es considerado Neutro')
    else:
      print('El alumno es considerado Promotor')

clasificar_nps(9)
# Out:
# El alumno es considerado Promotor

# %% [markdown]
# #Condicionales sin parametro y conversión de tipo de dato

# %%
def verificar_si_puede_conducir_sin_parametros ():
  edad = input ('Digite su edad:')
  edad = int (edad)
  if edad >= 18:
    print("Usted tiene edad suficiente para conducir")
  else:
    print ("Usted NO tiene edad suficiente para conducir")

verificar_si_puede_conducir_sin_parametros ()
# Out:
# Digite su edad:18
# Usted tiene edad suficiente para conducir

# %%
def permiso_de_conducir():
 edad = input('¿Cuál es tu edad? ')
 edad = int (edad)
 if edad >= 18:
   print('Ya tienes edad suficiente para obtener permiso de conducir')
 else:
   tiempo = 18 - edad
   print(f'Tranquilo, faltan {tiempo} año(s) para obtener permiso de conducir')

permiso_de_conducir()
# Out:
# ¿Cuál es tu edad? 20
# Ya tienes edad suficiente para obtener permiso de conducir

# %% [markdown]
# #Operadores de Python
#
# a==b	a igual a b
#
# a != b	a diferente de b
#
# a < b	a menor que b
#
# a > b	a mayor que b
#
# a <= b	a menor o igual a b
#
# a >= b	a mayor o igual a b

# %% [markdown]
# # Creando una lista

# %%
edad = 18
nombre = 'Soledad'

# %%
type (edad)
# Out:
# int

# %%
type (nombre)
# Out:
# str

# %%
edades = [18, 30, 45, 50, 55]

# %%
type (edades)
# Out:
# list

# %%
edades
# Out:
# [18, 30, 45, 50, 55]

# %%
edades[1]
# Out:
# 30

# %%
# [18, 30, 45, 50, 55]
#   0  1   2   3   4
edades[2]
# Out:
# 45

# %%
edades[0:3]
# Out:
# [18, 30, 45]

# %%
edades[:]
# Out:
# [18, 30, 45, 50, 55]

# %%
edades [1:]
# Out:
# [30, 45, 50, 55]

# %%
# [18, 30, 45, 50, 55]
#   0  1   2   3   4
#   0 -4  -3  -2  -1
edades[-1]
# Out:
# 55

# %%
edades[-3]
# Out:
# 45

# %%
frase_alura = [' Digitales', 'y ', 'Negocios ', 'de ', 'Tecnología ', 'Cursos ']
                #  0          1      2            3      4             5
                #  0         -5      -4          -3      -2           -1

# %% [markdown]
# #Bucles y Ciclos (Loops)

# %%
#Bucle fuera de la función
edades = [18, 30, 45, 50, 55]

def verificar_si_puede_conducir(edad):
  if edad >= 18:
    print("Usted tiene edad suficiente para conducir")
  else:
    print ("Usted NO tiene edad suficiente para conducir")

for edad in edades:
  verificar_si_puede_conducir(edad)
# Out:
# Usted tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir

# %%
#Bucle dentro de la función
edades=[18,15,12,45,50]

def verificar_si_puede_conducir_con_bucle(edades):
  for edad in edades:
    if edad >= 18:
      print("Usted tiene edad suficiente para conducir")
    else:
      print("Usted NO tiene edad suficiente para conducir")

verificar_si_puede_conducir_con_bucle(edades)
# Out:
# Usted tiene edad suficiente para conducir
# Usted NO tiene edad suficiente para conducir
# Usted NO tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir

# %%
def clasificar_nps(notas):
  for nota in notas:
    if nota <= 6:
      print('El alumno es considerado Detractor')
    else:
      if nota <= 8:
        print('El alumno es considerado Neutro')
      else:
        print('El alumno es considerado Promotor')

clasificar_nps([9,8,10,6,7])
# Out:
# El alumno es considerado Promotor
# El alumno es considerado Neutro
# El alumno es considerado Promotor
# El alumno es considerado Detractor
# El alumno es considerado Neutro

# %% [markdown]
# #Tipo Booleano

# %%
edad = 18

# %%
edad >=18
# Out:
# True

# %%
edad <18
# Out:
# False

# %%
edad==18
# Out:
# True

# %%
verificaciones = []
edades = [13,15,20]

def verificar_si_puede_conducir_bool (verificaciones, edades):
  for edad in edades:
    if edad >= 18:
      verificaciones.append(True)
    else:
      verificaciones.append(False)

verificar_si_puede_conducir_bool(verificaciones,edades)

# %%
verificaciones
# Out:
# [False, False, True]

# %%
verificaciones = []
edades = [13,15,20]

def verificar_si_puede_conducir_bool (verificaciones, edades):
  for edad in edades:
    if edad >= 18:
      verificaciones.append(True)
    else:
      verificaciones.append(False)
  for verificacion in verificaciones:
    if verificacion == True:
      print("Usted tiene edad suficiente para conducir")
    else:
      print("Usted NO tiene edad suficiente para conducir")

verificar_si_puede_conducir_bool(verificaciones,edades)
# Out:
# Usted NO tiene edad suficiente para conducir
# Usted NO tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir

# %%
a=2

if a < 2:
 a = a + 1
else:
 a = a + 2
if a < 4:
 a = a - 4
else:
 a = a + 6

a
# Out:
# 10

# %% [markdown]
# #Listas con diferentes tipos de datos

# %%
persona = ['Mariana', 25, True, 'Mexico']

# %%
persona
# Out:
# ['Mariana', 25, True, 'Mexico']

# %%
for elemento in persona:
  print(f'El elemento {elemento} de la lista es del tipo ', type (elemento))
# Out:
# El elemento Mariana de la lista es del tipo  <class 'str'>
# El elemento 25 de la lista es del tipo  <class 'int'>
# El elemento True de la lista es del tipo  <class 'bool'>
# El elemento Mexico de la lista es del tipo  <class 'str'>

# %%
lista = ['int', False, True, '18', 2020]

# %%
for elemento in lista:
 print(type(elemento))
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'bool'>
# <class 'str'>
# <class 'int'>

# %%
pi = 3.14
type(pi)
# Out:
# float

# %% [markdown]
# #Importando una bilioteca

# %%
from random import randrange

# %%
randrange(1,42)
# Out:
# 11

# %%
numeros_loto = []

# %%
numeros_loto.append(randrange (1,42))

# %%
numeros_loto
# Out:
# [39]

# %%
numeros_loto = []
for numeros in range (6):
  numeros_loto.append(randrange (1,42))

# %%
numeros_loto
# Out:
# [22, 30, 23, 18, 26, 17]

# %%
len (numeros_loto)
# Out:
# 6

# %%
from random import randrange, seed

# %%
numeros_loto = []
seed (15)
for numeros in range (6):
  numeros_loto.append(randrange (1,42))

# %%
numeros_loto
# Out:
# [14, 1, 34, 3, 11, 16]

# %%
from random import randrange
type(randrange)
# Out:
# method

# %% [markdown]
# #Biblioteca Matplotlib para gráficos

# %%
import matplotlib.pyplot as plt

# %%
list(range(1,7))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x = list(range(1,7))
y = numeros_loto

plt.plot (x,y, marker = 'o')
plt.title ('Sorteo 5010 Numeros del loto')
plt.xlabel ('Distribucion')
plt.ylabel ('Números')
plt.show ()

# %%
import matplotlib.pyplot as plt

notas_matematica = ['Matemática',8,7,6,6,7,7,8,10]
notas_lenguaje = ['Lenguaje',9,9,9,8,5,6,8,5]
notas_geografia = ['Geografía',10,10,6,7,7,7,8,7]

notas = [notas_matematica, notas_lenguaje, notas_geografia]

# %%
for nota in notas:
 x = list(range(1, 9))
 y = nota[1:]
 plt.plot(x, y, marker='o')
 plt.xlabel('Exámenes')
 plt.ylabel('Notas')
 plt.title(nota[0])
 plt.show()
